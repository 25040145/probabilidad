# %% [markdown]
# <a href="https://colab.research.google.com/github/25040145/probabilidad/blob/main/Unidad1/practica2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image](https://github.com/Jose-Gabriel-Rodriguez/Probabilidad/blob/main/Cintilla2025.png?raw=true)
#
# # **Probabilidad y Estadistica**
#
# ## **Unidad 1**
#
# ### Practica 2. Maximo, Minimo, Rango y dispersion de datos**
#
# ### Docente: *Dr. Jose Gabriel Rodriguez Rivas*
#
# ### Alumno: *Andree Osvaldo Moreno Serna*

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
fabrica1 = []
for i in range(100):
    numero_aleatorio = round(random.uniform(50, 100), 2)
    fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [72.01, 50.69, 79.8, 54.1, 92.94, 91.2, 51.08, 86.95, 85.6, 93.28, 87.44, 76.41, 61.41, 77.87, 99.02, 52.37, 98.54, 85.27, 79.96, 92.6, 61.84, 68.26, 56.11, 89.5, 57.18, 51.55, 62.21, 73.21, 92.12, 99.43, 78.39, 69.84, 81.27, 87.0, 68.94, 95.35, 82.6, 82.58, 83.55, 51.08, 70.39, 50.95, 71.14, 77.67, 60.29, 52.03, 66.55, 82.76, 63.21, 77.31, 76.34, 81.28, 64.63, 64.55, 55.24, 72.0, 79.29, 91.57, 54.88, 57.8, 95.12, 53.95, 54.41, 55.38, 51.31, 57.06, 96.97, 91.04, 94.58, 68.47, 98.03, 87.53, 74.87, 67.68, 68.1, 54.64, 57.18, 90.61, 84.18, 68.35, 55.94, 82.23, 94.23, 54.96, 86.87, 74.4, 65.25, 93.94, 89.27, 73.05, 97.21, 77.09, 89.71, 77.69, 97.73, 96.69, 64.85, 57.45, 57.05, 78.69]

# %%
fabrica2 = []
for i in range(100):
    numero_aleatorio = round(random.uniform(43, 97), 2)
    fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [69.23, 93.89, 80.74, 75.51, 88.72, 48.36, 78.63, 49.04, 67.45, 75.91, 56.9, 91.01, 67.49, 51.22, 89.2, 59.37, 51.95, 62.42, 49.88, 50.47, 56.4, 67.15, 53.38, 63.75, 67.78, 91.86, 78.43, 63.86, 79.46, 47.59, 90.42, 68.27, 73.9, 56.1, 56.09, 73.58, 50.13, 87.77, 85.1, 95.21, 90.0, 64.32, 78.02, 47.23, 60.95, 47.47, 81.76, 75.48, 80.26, 60.37, 68.66, 48.42, 69.75, 59.81, 79.61, 75.9, 63.45, 80.05, 88.61, 96.04, 86.17, 73.2, 57.3, 58.54, 49.47, 70.62, 60.61, 49.39, 69.93, 64.05, 44.86, 45.42, 76.37, 81.77, 70.11, 76.73, 90.57, 43.33, 65.33, 66.97, 91.84, 64.93, 71.69, 96.61, 89.86, 53.06, 69.51, 94.26, 96.07, 78.65, 79.28, 69.42, 54.65, 62.88, 83.74, 92.79, 69.92, 90.51, 57.3, 85.75]

# %% [markdown]
# Maximo, Minimo y Rango
#
# Estadistica de la fabrica 1

# %%
maximo1 = max(fabrica1)
minimo1 = min(fabrica1)
rango1 = maximo1 - minimo1
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

print("Estadistica descriptiva de la Fabrica 1 \n", "Media =", media1,
     "\n Mediana =", mediana1, "\n Moda= ", maximo1,
     "\n Minimo =", minimo1, "\n Rango =", rango1)
# Out:
# Estadistica descriptiva de la Fabrica 1
#  Media = 74.6419
#  Mediana = 76.375
#  Moda=  99.43
#  Minimo = 50.69
#  Rango = 48.74000000000001

# %% [markdown]
# Estadistica de la fabrica 2

# %%
maximo2 = max(fabrica2)
minimo2 = min(fabrica2)
rango2 = maximo2 - minimo2
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

print("Estadistica descriptiva de la Fabrica 1 \n", "Media =", media2,
     "\n Mediana =", mediana2, "\n Moda= ", maximo2,
     "\n Minimo =", minimo2, "\n Rango =", rango2)
# Out:
# Estadistica descriptiva de la Fabrica 1
#  Media = 70.3324
#  Mediana = 69.63
#  Moda=  96.61
#  Minimo = 43.33
#  Rango = 53.28

# %% [markdown]
# Histograma fabrica 2

# %%
plt.figure(figsize = ( 8, 6))
plt.hist(fabrica2, bins=10, alpha=0.2, color= 'b', edgecolor = "black")
plt.axvline(media2, color=  'b', linestyle='dashed', linewidth=2, label=f'Media={media2:.2f}')
plt.axvline(mediana2, color=  'r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana2:.2f}')
plt.axvline(moda2, color=  'y', linestyle='dashed', linewidth=2, label=f'moda={moda2:.2f}')

plt.axvline(media2 - desviacion_estandar_fabrica2, color='black', linestyle='dashed',
            linewidth=2, label=f'Desv. Estandar ={desviacion_estandar_fabrica2:.2f}')
plt.axvline(media2 + desviacion_estandar_fabrica2, color='black', linestyle=  'dashed',
            linewidth=2)

plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title('Produccion diaria de la fabrica 2')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2018742776.py in <cell line: 0>()
#       5 plt.axvline(moda2, color=  'y', linestyle='dashed', linewidth=2, label=f'moda={moda2:.2f}')
#       6
# ----> 7 plt.axvline(media2 - desviacion_estandar_fabrica2, color='black', linestyle='dashed',
#       8             linewidth=2, label=f'Desv. Estandar ={desviacion_estandar_fabrica2:.2f}')
#       9 plt.axvline(media2 + desviacion_estandar_fabrica2, color='black', linestyle=  'dashed',
#
# NameError: name 'desviacion_estandar_fabrica2' is not defined

# %%
plt.figure(figsize = ( 8, 6))
plt.hist(fabrica1, bins=10, alpha=0.2, color= 'b', edgecolor = "black")
plt.axvline(media1, color=  'b', linestyle='dashed', linewidth=2, label=f'Media={media1:.2f}')
plt.axvline(mediana1, color=  'r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana1:.2f}')
plt.axvline(moda1, color=  'y', linestyle='dashed', linewidth=2, label=f'moda={moda1:.2f}')
plt.axvline(media1 - desviacion_estandar_fabrica1, color='black', linestyle='dashed',
            linewidth=1, label=f'Desv. Estandar ={desviacion_estandar_fabrica1:.2f}')
plt.axvline(media1 + desviacion_estandar_fabrica1, color='black', linestyle=  'dashed',
            linewidth=2)

plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title('Produccion diaria de la fabrica 1')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3902872481.py in <cell line: 0>()
#       4 plt.axvline(mediana1, color=  'r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana1:.2f}')
#       5 plt.axvline(moda1, color=  'y', linestyle='dashed', linewidth=2, label=f'moda={moda1:.2f}')
# ----> 6 plt.axvline(media1 - desviacion_estandar_fabrica1, color='black', linestyle='dashed',
#       7             linewidth=1, label=f'Desv. Estandar ={desviacion_estandar_fabrica1:.2f}')
#       8 plt.axvline(media1 + desviacion_estandar_fabrica1, color='black', linestyle=  'dashed',
#
# NameError: name 'desviacion_estandar_fabrica1' is not defined

# %%
plt.figure(figsize = ( 8, 6))
plt.hist(fabrica2, bins=10, alpha=0.2, color= 'b', edgecolor = "black")
plt.axvline(media2, color=  'b', linestyle='dashed', linewidth=2, label=f'Media={media2:.2f}')
plt.axvline(mediana2, color=  'r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana2:.2f}')
plt.axvline(moda2, color=  'y', linestyle='dashed', linewidth=2, label=f'moda={moda2:.2f}')

plt.axvline(media2 - desviacion_estandar_fabrica2, color='black', linestyle='dashed',
            linewidth=2, label=f'Desv. Estandar ={desviacion_estandar_fabrica2:.2f}')
plt.axvline(media2 + desviacion_estandar_fabrica2, color='black', linestyle=  'dashed',
            linewidth=2)

plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title('Produccion diaria de la fabrica 2')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2018742776.py in <cell line: 0>()
#       5 plt.axvline(moda2, color=  'y', linestyle='dashed', linewidth=2, label=f'moda={moda2:.2f}')
#       6
# ----> 7 plt.axvline(media2 - desviacion_estandar_fabrica2, color='black', linestyle='dashed',
#       8             linewidth=2, label=f'Desv. Estandar ={desviacion_estandar_fabrica2:.2f}')
#       9 plt.axvline(media2 + desviacion_estandar_fabrica2, color='black', linestyle=  'dashed',
#
# NameError: name 'desviacion_estandar_fabrica2' is not defined

# %%
import seaborn as sns

# %%
# La densidad grafica es una forma de visuaizar la distribucion de datos en
# un intervalo o periodo de tiempo continuo.
# Se basa en un histograma que usa el suavizado de kernel para trazar valores,
# lo que permite obtener distribuciones mas suaves al reducir el ruido.
# Una curva  de densidad muestra la ubicacion de la media y la mediana de una distribucion

sns.histplot( x = fabrica1, kde = True, kde_kws = {'bw_adjust': 0.5}, bins = 10)
# Out:
# <Axes: ylabel='Count'>
