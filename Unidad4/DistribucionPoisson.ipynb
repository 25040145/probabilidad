# %% [markdown]
# <a href="https://colab.research.google.com/github/25040145/probabilidad/blob/main/Unidad4/DistribucionPoisson.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy.stats import poisson

# Parametros de la distribucion de poisson
media_accidentes = 2

# Parte 1: Probabilidad de que no haya accidentes en 1 semana
probabilidad_0_accidentes = poisson.pmf(0, media_accidentes)

print("1. Probabilidad de que no haya accidentes en 1 semana es DE:", probabilidad_0_accidentes)

# Parte 2: Probabilidad de que la suma haya tres accidesntes en 2 semanas
# Convertimos la media a una media para 2 semanas
media_2_semanas = media_accidentes * 2

# Calculamos la probabilidad acumulada hasta 3 accidentes en 2 semanas
probabilidad_3_o_menos_accidentes = poisson.cdf(3, media_2_semanas)

print("2. Probabilidad de que la suma haya tres accidentes en 2 semanas es DE:", probabilidad_3_o_menos_accidentes)
# Out:
# 1. Probabilidad de que no haya accidentes en 1 semana es DE: 0.1353352832366127
# 2. Probabilidad de que la suma haya tres accidentes en 2 semanas es DE: 0.43347012036670896

# %%
from scipy.stats import poisson

# Parametros de la distribucion de poisson
media_muertes = 5000 * 0.001 # 5000 hombres con una probabilidad de muerte de 0.001

# Numero de reclamaciones
x = 4

# Calcular la probabilidad de que la compañia tenga que pagar 4 reclamaciones en un año determinado
probabilidad_4_reclamaciones = poisson.pmf(x, media_muertes)

print(f"La probabilidad de que la compañia tenga que pagar 4 reclamaciones es DE:", probabilidad_4_reclamaciones)
# Out:
# La probabilidad de que la compañia tenga que pagar 4 reclamaciones es DE: 0.17546736976785063
