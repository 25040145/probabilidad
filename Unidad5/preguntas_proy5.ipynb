# %% [markdown]
# <a href="https://colab.research.google.com/github/25040145/probabilidad/blob/main/Unidad5/preguntas_proy5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. ¿Explicar cual es la interpretacion del coeficiente de regresion en terminos de la relacion entre el tiempo de estudio y las calificaciones finales?
# en el grupo 1 por cada una hora de estudio, la calificaion final va aumentar un -0.16 puntos, asi que tiene un impacto positivo.
# en grupo 2 Por cada hora adicional de estudio, la calificación aumenta en promedio 4.22 puntos.
# y en el grupo 3 Por cada hora adicional de estudio, la calificación aumenta en promedio 5.29 puntos.

# %% [markdown]
# 2. ¿como se interpreta el coeficiente de correlacion en terminos de la fuerza y direccion de la relacion entre las variables?
# r = –0.057 → relación prácticamente nula y negativa
# No existe relación entre horas de estudio y calificación.
#
# Grupo 2
#
# r = 0.862 → relación positiva muy fuerte
# Más horas de estudio → mejores calificaciones.
#
# Grupo 3
#
# r = 0.942 → relación positiva extremadamente fuerte
# Las horas de estudio explican muy bien el desempeño.

# %% [markdown]
# 3. ¿el modelo de regresion lineal es estadisticamente significativo?
#
# Grupo	    p-valor	   ¿Significativo?
#
# Grupo 1	  0.6935	   NO significativo
#
# Grupo 2	  9.07e-16	 Sí significativo
#
# Grupo 3	  1.93e-24	 Sí significativo

# %% [markdown]
# 4. ¿que tan confiable es el modelo de regresion para predecir las calificaciones finales de los estudiantes basado en el tiempo de estudio?
#
#
# Grupo 1
#
# R² = 0.003 El modelo no predice nada.
#
#
# Grupo 2
#
# R² = 0.743
# → El 74.3% de la variación en calificaciones se explica por las horas estudiadas.
# Modelo bastante confiable.
#
#
# Grupo 3
#
# R² = 0.888
# → El 88.8% de las calificaciones se explica por horas estudiadas.
# Modelo muy confiable.
